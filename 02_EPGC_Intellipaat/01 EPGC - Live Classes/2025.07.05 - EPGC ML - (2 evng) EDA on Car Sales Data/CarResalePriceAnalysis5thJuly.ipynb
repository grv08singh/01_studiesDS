# %% [markdown]
# # **Car Resale Price Analysis & Visualization System**
#
# ## **Problem Statement**
#  You are a data analyst working for a car dealership. You have received a CSV file containing sales data.
#  Your goal is to understand the sales pattern, customer behavior, and make visual insights using Python basics,
#  Object-Oriented Programming (OOP), NumPy, Pandas, Matplotlib, and Seaborn.
#
# **Your job includes:**
# - Data cleaning and preprocessing
# - Basic analysis
# - **OOP implementation**
# - Visualization
# - Extracting insights

# %% [markdown]
# Dataset Link - https://drive.google.com/file/d/13_hVAChDiDSmpvvZYC4shMZkCYPqCMK2/view?usp=sharing

# %% [markdown]
# **Import Necessary Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load our Dataset**

# %%
df = pd.read_csv('/content/daTA.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# **Insight**
# * Selling Price and Present Prince is in lakh means 3.35 -> 3.35 lakhs

# %% [markdown]
# **Shape Inspection**

# %%
a = df.shape # Attribute
print(f'Rows: {a[0]} and Columns are: {a[1]}')
# Out:
# Rows: 301 and Columns are: 9

# %% [markdown]
# **Data information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# **Insight**
# * There is no null values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# **If you have null value**
# * Drop the null values
# * Fill null values ->  Mean, Median, mode, Constant

# %%
df.Car_Name.unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
df.Car_Name.nunique() # There are 98 different cars we have in our dataset
# Out:
# 98

# %%
df.Car_Name.value_counts()
# Out:
# Car_Name
# city                  26
# corolla altis         16
# verna                 14
# fortuner              11
# brio                  10
#                       ..
# Honda Activa 125       1
# Hero Hunk              1
# Hero  Ignitor Disc     1
# Hero  CBZ Xtreme       1
# Bajaj  ct 100          1
# Name: count, Length: 98, dtype: int64

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# **Add a new column -> Age of Car**

# %%
currentYear = 2025
df['Car_Age'] = currentYear - df['Year']
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age
# 0      Dealer       Manual      0       11
# 1      Dealer       Manual      0       12
# 2      Dealer       Manual      0        8
# 3      Dealer       Manual      0       14
# 4      Dealer       Manual      0       11

# %%
# pd.Timestamp.now().year To get the current time

# %% [markdown]
# **how Depreciation affects the value of car**

# %%
df['Depreciation'] = df['Present_Price'] - df['Selling_Price']
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age  Depreciation
# 0      Dealer       Manual      0       11          2.24
# 1      Dealer       Manual      0       12          4.79
# 2      Dealer       Manual      0        8          2.60
# 3      Dealer       Manual      0       14          1.30
# 4      Dealer       Manual      0       11          2.27

# %% [markdown]
# **Let's see how wear and tear the car gets based in total km**

# %%
df['kms_driven_per_year'] = df['Kms_Driven'] / df['Car_Age']
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Car_Age  Depreciation  kms_driven_per_year
# 0      Dealer       Manual      0       11          2.24          2454.545455
# 1      Dealer       Manual      0       12          4.79          3583.333333
# 2      Dealer       Manual      0        8          2.60           862.500000
# 3      Dealer       Manual      0       14          1.30           371.428571
# 4      Dealer       Manual      0       11          2.27          3859.090909

# %% [markdown]
# **Rename some columns**

# %%
# df = df.rename(columns={
#     'Car_Name' : 'Brand',
#     'Present_Price' : 'Price'
# })

df.rename(columns={
    'Car_Name' : 'Brand',
    'Present_Price' : 'Price'
},inplace = True)

# %%
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_Age  Depreciation  kms_driven_per_year
# 0       Manual      0       11          2.24          2454.545455
# 1       Manual      0       12          4.79          3583.333333
# 2       Manual      0        8          2.60           862.500000
# 3       Manual      0       14          1.30           371.428571
# 4       Manual      0       11          2.27          3859.090909

# %% [markdown]
# **Numpy Implimentation**
# * Classify Price segment using numpy (np.where)

# %%
price_array = df['Price'].values# All the price values will be taken into price_array Variable
price_segmenet = np.where(price_array>20 , 'Luxury','Standard')
df['Segment'] = price_segmenet

# %%
df.head()
# Out:
#      Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1      sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2     ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3  wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4    swift  2014           4.60   6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Car_Age  Depreciation  kms_driven_per_year   Segment
# 0       Manual      0       11          2.24          2454.545455  Standard
# 1       Manual      0       12          4.79          3583.333333  Standard
# 2       Manual      0        8          2.60           862.500000  Standard
# 3       Manual      0       14          1.30           371.428571  Standard
# 4       Manual      0       11          2.27          3859.090909  Standard

# %% [markdown]
# **Let's see overall Stats value**

# %%
df.describe()
# Out:
#               Year  Selling_Price       Price     Kms_Driven       Owner  \
# count   301.000000     301.000000  301.000000     301.000000  301.000000
# mean   2013.627907       4.661296    7.628472   36947.205980    0.043189
# std       2.891554       5.082812    8.644115   38886.883882    0.247915
# min    2003.000000       0.100000    0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000    1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000    6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000    9.900000   48767.000000    0.000000
# max    2018.000000      35.000000   92.600000  500000.000000    3.000000
#
#           Car_Age  Depreciation  kms_driven_per_year
# count  301.000000    301.000000           301.000000
# mean    11.372093      2.967176          3034.762560
# std      2.891554      4.828771          2437.178310
# min      7.000000      0.030000            55.555556
# ...

# %%
df.describe().T
# Out:
#                      count          mean           std          min       25%  \
# Year                 301.0   2013.627907      2.891554  2003.000000   2012.00
# Selling_Price        301.0      4.661296      5.082812     0.100000      0.90
# Price                301.0      7.628472      8.644115     0.320000      1.20
# Kms_Driven           301.0  36947.205980  38886.883882   500.000000  15000.00
# Owner                301.0      0.043189      0.247915     0.000000      0.00
# Car_Age              301.0     11.372093      2.891554     7.000000      9.00
# Depreciation         301.0      2.967176      4.828771     0.030000      0.39
# kms_driven_per_year  301.0   3034.762560   2437.178310    55.555556   1500.00
#
#                           50%           75%            max
# Year                  2014.00   2016.000000    2018.000000
# Selling_Price            3.60      6.000000      35.000000
# Price                    6.40      9.900000      92.600000
# ...

# %% [markdown]
# **Insight**
# * Maximum Price of a car is 92 lac ruppes
# * On an average the year of car we have is 11 years
# * Approx 3000 km was driven by cars on average in a year
# * Most of the car had the price less than 10 lack

# %%
df.describe(include='O').T # Include O means we are trying to find stats data for object Data type
# Out:
#              count unique       top freq
# Brand          301     98      city   26
# Fuel_Type      301      3    Petrol  239
# Seller_Type    301      2    Dealer  195
# Transmission   301      2    Manual  261
# Segment        301      2  Standard  282

# %% [markdown]
# * **Most frequency of car we are getting from honda City**
# * Petrol car are maximum bought
# * Mostly manual cars are being prefered

# %%
df.describe(include= 'all').T
# Out:
#                      count unique       top freq         mean           std  \
# Brand                  301     98      city   26          NaN           NaN
# Year                 301.0    NaN       NaN  NaN  2013.627907      2.891554
# Selling_Price        301.0    NaN       NaN  NaN     4.661296      5.082812
# Price                301.0    NaN       NaN  NaN     7.628472      8.644115
# Kms_Driven           301.0    NaN       NaN  NaN  36947.20598  38886.883882
# Fuel_Type              301      3    Petrol  239          NaN           NaN
# Seller_Type            301      2    Dealer  195          NaN           NaN
# Transmission           301      2    Manual  261          NaN           NaN
# Owner                301.0    NaN       NaN  NaN     0.043189      0.247915
# Car_Age              301.0    NaN       NaN  NaN    11.372093      2.891554
# Depreciation         301.0    NaN       NaN  NaN     2.967176      4.828771
# ...

# %% [markdown]
# **Let's Use GroupBY method to check brand wise average price**

# %%
brandWiseAveragePrice = df.groupby('Brand')['Price'].mean()

# %%
brandWiseAveragePrice
# Out:
# Brand
# 800                  2.280000
# Activa 3g            0.530000
# Activa 4g            0.510000
# Bajaj  ct 100        0.320000
# Bajaj Avenger 150    0.800000
#                        ...
# sx4                  8.066667
# verna                9.400000
# vitara brezza        9.830000
# wagon r              4.450000
# xcent                7.130000
# Name: Price, Length: 98, dtype: float64

# %% [markdown]
# ###**Visualization**
# **Categorical Visualiztion**
# * Fuel Type

# %%
sns.countplot(x='Fuel_Type',data=df)
plt.title('Fuel Types Distribution')
plt.show()

# %% [markdown]
# **Insight**
# * Petrol is mostly used followed by Diseal vehical
# * CNG is least prefered fuel Type

# %% [markdown]
# **Seller Type**

# %%
df.columns # All name of columns
# Out:
# Index(['Brand', 'Year', 'Selling_Price', 'Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_Age', 'Depreciation',
#        'kms_driven_per_year', 'Segment'],
#       dtype='object')

# %%
sns.countplot(x='Seller_Type',data=df)
plt.title('Seller Type Distribution')
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight**
# * Customers are buying more cars from Dealer rather than choosing individuals

# %% [markdown]
# **Transmission**

# %%
sns.countplot(x = 'Transmission', data=df)
plt.title('Transmission Type Distribution')
plt.show()

# %% [markdown]
# **Insights**
# * More manual cars are there in carResale shop
#     * Maybe because we have the data where the cars are 11 year old on an average

# %%
sns.countplot(data=df, x='Transmission', hue='Year')
# Out:
# <Axes: xlabel='Transmission', ylabel='count'>

# %%
sns.countplot(data=df, x='Year', hue='Transmission')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Insight** - HW for you guys

# %% [markdown]
# **Relationship visualization**

# %%
sns.scatterplot(x = 'Price',y='Selling_Price',data=df)
plt.title('Present Price vs Selling Price')
plt.show()

# %% [markdown]
# **Insight**
# * higher the present price will be, higher the selling price will be (Positive Trend)
# * Increase is not equal = selling price grows slower at higher present price
# * One or two outliers with very high present price and selling price -> we can remove the outlier -> IQR
# * Most data points are between 0-20 lakhs, that shows the price of car

# %%
sns.scatterplot(x = 'Kms_Driven', y ='Selling_Price',data= df)
plt.title('kms driven vs selling price')
plt.show()

# %% [markdown]
# **Insights**
# * more the km driven, less the price (inversly prop)
# * High Milage cars (Driven more) usually sold for less price
# * Most cars are driven under 100000

# %% [markdown]
# **Trend Analysis**
# * Average Selling Price by car Age

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Selling_Price', 'Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_Age', 'Depreciation',
#        'kms_driven_per_year', 'Segment'],
#       dtype='object')

# %%
sns.lineplot(x = 'Car_Age', y ='Selling_Price',data=df,marker='o')
plt.title('Selling price trend based on car age')
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight**
# * When the car is getting old, the selling price (worth) starts declining
# * It can be possible that there was some vehical which was 18 years old and was in very bad condition

# %%
sns.lineplot(x='Fuel_Type',y='Selling_Price',data=df)
plt.title('Selling price based on fuel type')
plt.show()

# %% [markdown]
# **Insight**
# * Diesel cars are selling more as compared to Petrol and CNG (Diseal is cheaper than petrol and can be better for commute than CNG)
# * petrol has cars & bikes --> less avg price....... diesel has cars only --> more avg price....

# %% [markdown]
# **Value Depreciation Trend**

# %%
sns.lineplot(x='Car_Age', y = 'Depreciation', data= df)
plt.title('Car Age vs depreciation')
plt.show()

# %% [markdown]
# **Insight**
# * The more the car will be old, the more depreciation rate will increase

# %%
df.columns
# Out:
# Index(['Brand', 'Year', 'Selling_Price', 'Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'Car_Age', 'Depreciation',
#        'kms_driven_per_year', 'Segment'],
#       dtype='object')

# %%
summary = df.groupby('Fuel_Type')[['Selling_Price','Depreciation','kms_driven_per_year']].mean()
summary
# Out:
#            Selling_Price  Depreciation  kms_driven_per_year
# Fuel_Type
# CNG             3.100000      3.315000          3560.642857
# Diesel         10.278500      5.536000          4395.279595
# Petrol          3.264184      2.319372          2688.809494

# %% [markdown]
# **Insight**
# * **Based on Selling price**
#     * Diseal cars have the highest average selling price
#     * on average petrol cars are sold for 3 lac ruppees
# * **Based on Depreciation**
#     * Diseal car lose the most value over the time ( mostly car only)
#     * Petrol has the least depreciation (Bike also)
# * **Based on km driven per year**
#     * Diesel cars are driven the most (4395 km/year)
#     * Petrol car the least 2688 km/year

# %% [markdown]
# Final Insights for fuel type vehicals
# * Diesel : More expensive, Depreciation is more, drive more -> can be better fot longer travel
# * Petrol : Petriol vehicals are cheaper, depreciate less, are used more freqent
# * CNG : More Cost effective option -> because it lies in between Diesel and petrol

# %% [markdown]
# Average Depreciation Rate

# %%
df['Depreciation_%'] = np.round((df['Depreciation'] / df['Price'])*100,2)
df
# Out:
#        Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1        sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2       ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3    wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4      swift  2014           4.60   6.87       42450    Diesel      Dealer
# ..       ...   ...            ...    ...         ...       ...         ...
# 296     city  2016           9.50  11.60       33988    Diesel      Dealer
# 297     brio  2015           4.00   5.90       60000    Petrol      Dealer
# 298     city  2009           3.35  11.00       87934    Petrol      Dealer
# 299     city  2017          11.50  12.50        9000    Diesel      Dealer
# 300     brio  2016           5.30   5.90        5464    Petrol      Dealer
#
# ...

# %%
avg_dep = np.mean(df['Depreciation_%'])
avg_dep
# Out:
# np.float64(36.55455149501662)

# %% [markdown]
# On average the depreciation rate of a vehical is 37%

# %%
df['depPerYear'] = df['Depreciation_%'] / df['Car_Age']

# %%
df
# Out:
#        Brand  Year  Selling_Price  Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz  2014           3.35   5.59       27000    Petrol      Dealer
# 1        sx4  2013           4.75   9.54       43000    Diesel      Dealer
# 2       ciaz  2017           7.25   9.85        6900    Petrol      Dealer
# 3    wagon r  2011           2.85   4.15        5200    Petrol      Dealer
# 4      swift  2014           4.60   6.87       42450    Diesel      Dealer
# ..       ...   ...            ...    ...         ...       ...         ...
# 296     city  2016           9.50  11.60       33988    Diesel      Dealer
# 297     brio  2015           4.00   5.90       60000    Petrol      Dealer
# 298     city  2009           3.35  11.00       87934    Petrol      Dealer
# 299     city  2017          11.50  12.50        9000    Diesel      Dealer
# 300     brio  2016           5.30   5.90        5464    Petrol      Dealer
#
# ...

# %%
sns.lineplot(x=df['Fuel_Type'],y=df['depPerYear'])
plt.show()

# %% [markdown]
# **Insight**
# * Diesel vehical is having less depreciation per year as compared to Petrol and CNG
