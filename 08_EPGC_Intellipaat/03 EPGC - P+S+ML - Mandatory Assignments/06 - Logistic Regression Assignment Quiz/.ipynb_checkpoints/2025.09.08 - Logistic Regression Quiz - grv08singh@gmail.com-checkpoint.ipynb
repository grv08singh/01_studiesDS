# %%
#Logistic Regression Quiz
#Gaurav Singh - grv08singh@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv("census-income .csv")

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
df.columns.to_list()
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'annual_income']

# %%
df['occupation'].nunique()
# Out:
# 15

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(df[col].value_counts())
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# ...

# %%
df1 = df.drop_duplicates()

# %%
#Q2 - Answer not match



df1[(df1['occupation'] == 'Tech-support') & (df1['annual_income'] == '>50K')]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 25      56         Local-gov  216851     Bachelors             13
# 55      43           Private  237993  Some-college             10
# 248     40           Private  207578    Assoc-acdm             12
# 357     40           Private   96129     Assoc-voc             11
# 469     30           Private  118551     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 31510   42           Private  111483     Bachelors             13
# 31653   25           Private  189656     Bachelors             13
# 31807   51  Self-emp-not-inc  170086     Bachelors             13
# 32076   59       Federal-gov  293971  Some-college             10
# 32457   33           Private  139057       Masters             14
#
#            marital-status    occupation   relationship                race  \
# 25     Married-civ-spouse  Tech-support        Husband               White
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df2 = df.replace('?', np.nan)

# %%
df2.isnull().sum().sum()
# Out:
# 4262

# %%
#Q5 - Answer not match



df2[(df2['workclass'] == 'Private') & (df2['native-country'] != 'United-States')]
# Out:
#        age workclass  fnlwgt  education  education-num         marital-status  \
# 4       28   Private  338409  Bachelors             13     Married-civ-spouse
# 6       49   Private  160187        9th              5  Married-spouse-absent
# 14      40   Private  121772  Assoc-voc             11     Married-civ-spouse
# 15      34   Private  245487    7th-8th              4     Married-civ-spouse
# 35      48   Private  242406       11th              7          Never-married
# ...    ...       ...     ...        ...            ...                    ...
# 32508   45   Private  155093       10th              6               Divorced
# 32510   39   Private  107302    HS-grad              9     Married-civ-spouse
# 32533   54   Private  337992  Bachelors             13     Married-civ-spouse
# 32547   43   Private  260761    HS-grad              9     Married-civ-spouse
# 32553   32   Private  116138    Masters             14          Never-married
#
# ...

# %%
#Q6 Answer not match


df3 = df2[(df2['annual_income'] == '<=50K') | (df2['hours-per-week'] >= 40)]
df4 = df3[(df3['annual_income'] == '<=50K') & (df3['hours-per-week'] >= 40)]
print(df3.shape[0])
print(df4.shape[0])
df3.shape[0] - df4.shape[0]
# Out:
# 31823
# 17695
# 14128

# %%
df2.columns.to_list()
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'annual_income']

# %%
df2.rename(columns={'annual_income' : 'Annual Income'},inplace = True)

# %%
df2.columns.to_list()
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'Annual Income']

# %%
df3 = df2.dropna()

# %%
df2.isnull().sum().sum()
# Out:
# 4262

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %%
df3.shape
# Out:
# (30162, 15)

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for col in df3.columns:
   if(df3[col].dtype == 'object'):
       df3[col] = LE.fit_transform(df3[col])

# %%
X = df3.iloc[:,0:-1]
y = df3['Annual Income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
y_pred = log.predict(X_test)

# %%
from sklearn.metrics import *
print(accuracy_score(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
# 0.7926842745054702
# array([[6627,  137],
#        [1739,  546]], dtype=int64)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
specificity = tn / (tn + fp)

# %%
specificity
# Out:
# 0.979745712596097

# %%
tn / (tn + fn)
# Out:
# 0.7921348314606742

# %%
tp + tn
# Out:
# 7173

# %%
tp + tn + fp + fn
# Out:
# 9049

# %%
precision = tp / (tp + fp)
recall = tp / (tp + fn)
f1_score = 2 * precision * recall / (precision + recall)
f1_score
# Out:
# 0.3679245283018867

# %%
tp + tn
# Out:
# 7173

# %%
#Creditworthyness Data

# %%
df4 = pd.read_excel('CreditWorthiness.xlsx', sheet_name='Data')

# %%
df4.columns.to_list()
# Out:
# ['Cbal',
#  'Cdur',
#  'Chist',
#  'Cpur',
#  'Camt',
#  'Sbal',
#  'Edur',
#  'InRate',
#  'MSG',
#  'Oparties',
#  'Rdur',
#  'Prop',
#  'age',
#  'inPlans',
#  'Htype',
#  'NumCred',
#  'JobType',
#  'Ndepend',
#  'telephone',
#  'foreign',
#  'creditScore']

# %%
df4['Htype'].value_counts()
for item in df4['Htype'].value_counts()[0]:
    prob.append()
# Out:
# Htype
# own          713
# pays rent    179
# free         108
# Name: count, dtype: int64

# %%
probs = np.array([713/(713+179+108), 179/(713+179+108), 108/(713+179+108)])
entropy = (-1 * np.sum(np.log2(probs) * probs))
entropy
# Out:
# 1.1390117663236383

# %%
df4.columns.to_list()
# Out:
# ['Cbal',
#  'Cdur',
#  'Chist',
#  'Cpur',
#  'Camt',
#  'Sbal',
#  'Edur',
#  'InRate',
#  'MSG',
#  'Oparties',
#  'Rdur',
#  'Prop',
#  'age',
#  'inPlans',
#  'Htype',
#  'NumCred',
#  'JobType',
#  'Ndepend',
#  'telephone',
#  'foreign',
#  'creditScore']

# %%
df4[(df4['age'] >= 25) & (df4['age'] <= 50) & (df4['inPlans'] == 'bank') & ((df4['Cpur'] == 'Business') | (df4['Cpur'] == 'electronics')) & (df4['foreign'] == 'yes')]
# Out:
# Empty DataFrame
# Columns: [Cbal, Cdur, Chist, Cpur, Camt, Sbal, Edur, InRate, MSG, Oparties, Rdur, Prop, age, inPlans, Htype, NumCred, JobType, Ndepend, telephone, foreign, creditScore]
# Index: []
#
# [0 rows x 21 columns]

# %%
df4[(df4['age'] >= 25) & (df4['age'] <= 50) & (df4['inPlans'] == 'bank') & ((df4['Cpur'] == 'Business') | (df4['Cpur'] == 'electronics')) & (df4['foreign'] == 'Yes')].shape[0]
# Out:
# 0

# %%
df4['foreign'].value_counts()
# Out:
# foreign
# no     963
# yes     37
# Name: count, dtype: int64

# %%
pd.get_dummies()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[241], line 1
# ----> 1 pd.get_dummies()
#
# TypeError: get_dummies() missing 1 required positional argument: 'data'

# %%
pd.get_dummies(df4)
# Out:
#      Cdur    Camt  InRate  age  NumCred  Ndepend  Cbal_ Rs. < 0  \
# 0       9   13790       2   27        1        1          False
# 1      15   15250       4   50        2        1          False
# 2      36   19410       4   61        1        1          False
# 3      48  144090       2   25        1        1          False
# 4      24   31690       4   26        1        1          False
# ..    ...     ...     ...  ...      ...      ...            ...
# 995     6    7710       1   26        1        2          False
# 996    12   64560       2   52        1        1          False
# 997    36   95540       2   31        2        1          False
# 998    18   19490       3   23        1        1          False
# 999    36   62170       4   23        2        1           True
#
#      Cbal_0 <= Rs. < 2000  Cbal_Rs. >=2000  Cbal_no checking account  ...  \
# 0                    True            False                     False  ...
# ...
